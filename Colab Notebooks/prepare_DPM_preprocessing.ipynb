# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp gdrive/MyDrive/dontpatronizeme_pcl.tsv .
# !cp gdrive/MyDrive/dontpatronizeme_categories.tsv .
# !cp gdrive/MyDrive/train_semeval_parids-labels.csv .
# !cp gdrive/MyDrive/dev_semeval_parids-labels.csv .
# !cp gdrive/MyDrive/DPM_preprocessing.py .

# %%
import random
import string
import os
from urllib import request

# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.2-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.0 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.2

# %%
from DPM_preprocessing import DPM_preprocessing
dpm = DPM_preprocessing('.', 'dontpatronizeme_pcl.tsv')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
dpm.load_task1()
dpm.train_task1_df.head()
# Out:
#   par_id      art_id  ... label orig_label
# 0      1  @@24942188  ...     0          0
# 1      2  @@21968160  ...     0          0
# 2      3  @@16584954  ...     0          0
# 3      4   @@7811231  ...     0          0
# 4      5   @@1494111  ...     0          0
#
# [5 rows x 7 columns]

# %%
dpm.train_task1_df.shape
# Out:
# (10469, 7)

# %%
dpm.load_task2()
dpm.train_task2_df.head()
# Out:
# Map of label to numerical label:
# {'Unbalanced_power_relations': 0, 'Shallow_solution': 1, 'Presupposition': 2, 'Authority_voice': 3, 'Metaphors': 4, 'Compassion': 5, 'The_poorer_the_merrier': 6}
#   par_id      art_id  ... country                  label
# 0   4046  @@14767805  ...      us  [1, 0, 0, 1, 0, 0, 0]
# 1   1279   @@7896098  ...      ng  [0, 1, 0, 0, 0, 0, 0]
# 2   8330  @@17252299  ...      ng  [0, 0, 1, 0, 0, 0, 0]
# 3   4063   @@3002894  ...      ie  [1, 0, 0, 1, 1, 1, 0]
# 4   4089  @@25597822  ...      pk  [1, 0, 0, 0, 0, 0, 0]
#
# [5 rows x 6 columns]

# %%
dpm.train_task2_df.shape
# Out:
# (993, 6)

# %% [markdown]
# invoke preprocessing when load_all_positive

# %%
dpm.load_all_positive()
dpm.all_positive_df.head(20)
# Out:
#    par_id  ...                                          text_span
# 0    4046  ...                 put their situation in perspective
# 1    4046  ...                 put their situation in perspective
# 2    4046  ...                 put their situation in perspective
# 3    4046  ...                  help them communicate with others
# 4    4046  ...                  help them communicate with others
# 5    4046  ...                  help them communicate with others
# 6    4046  ...                          who could provide support
# 7    4046  ...                          who could provide support
# 8    4046  ...                          who could provide support
# 9    4046  ...  plan for their needs and the needs of their child
# 10   4046  ...  plan for their needs and the needs of their child
# 11   4046  ...  plan for their needs and the needs of their child
# 12   4046  ...                 we also know that they can benefit
# 13   4046  ...                 we also know that they can benefit
# 14   4046  ...                 we also know that they can benefit
# 15   4046  ...  someone knowledgeable about resources they can...
# 16   4046  ...  someone knowledgeable about resources they can...
# 17   4046  ...  someone knowledgeable about resources they can...
# 18   1279  ...  washed and kissed the feet of muslim , orthodo...
# 19   1279  ...  washed and kissed the feet of muslim , orthodo...
#
# [20 rows x 7 columns]

# %%
dpm.all_positive_df.shape
# Out:
# (8280, 7)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = dpm.all_positive_df
df1 = df1.rename(columns={'text': 'sentence'})
df1 = df1.assign(label=1)
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))
df1 = df1.drop(['art_id', 'keyword', 'country', 'text_span'], axis = 1)

# Display 10 random rows from the data.
df1.sample(10)
# Out:
# Number of training sentences: 8,280
#      par_id                                           sentence  label
# 2270   4963   sa s main charity is the dignity dreams proje...      1
# 1251   1961   simply allowed and even encouraged their pros...      1
# 6523   7349   charity has a number of success stories where...      1
# 4150   6623   making the wishes of vulnerable hong kongborn...      1
# 2998   4160   is worth noting that 23 children coming from ...      1
# 5618   1490   people with disabily have the rights to be be...      1
# 1451   9006   jesus is the master feminist because he champ...      1
# 1623   5955   indigenous palestinians see themselves abando...      1
# 2444   9488   tensions eased and hopeless young people were...      1
# 3248   3268            even more so until elizabeth came along      1

# %%
dpm.all_positive_df.shape
# Out:
# (8280, 7)

# %%
dpm.load_all_negative()
dpm.all_negative_df.head()
# Out:
#   par_id      art_id  ... label orig_label
# 0      1  @@24942188  ...     0          0
# 1      2  @@21968160  ...     0          0
# 2      3  @@16584954  ...     0          0
# 3      4   @@7811231  ...     0          0
# 4      5   @@1494111  ...     0          0
#
# [5 rows x 7 columns]

# %%
dpm.all_negative_df.shape
# Out:
# (9476, 7)

# %%
df2 = dpm.all_negative_df
df2 = df2.rename(columns={'text': 'sentence'})
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))
df2 = df2.drop(['art_id', 'keyword', 'country', 'orig_label'], axis = 1)

# Display 10 random rows from the data.
df2.sample(10)
# Out:
# Number of training sentences: 8,280
#      par_id                                           sentence  label
# 9402  10385  miliband said he wanted to shift the governmen...      0
# 4287   4739  a week after releasing the new definition the ...      0
# 289     318                             the filipino immigrant      0
# 7167   7929  the united nations has also indicated that som...      0
# 1090   1222  apart from housing activists rightfully fighti...      0
# 6262   6926  in hyderabad there are 3800 rohangiyas with re...      0
# 1661   1859   i have heard the homeless described as vermin...      0
# 2887   3208   but we categorically do nt accept any street ...      0
# 859     961  ann s cottage has cared for disabled children ...      0
# 2308   2564  lawas the charred remains of a disabled teenag...      0

# %%
import pandas as pd
frames = [df1, df2]
newDf = pd.concat(frames)

from sklearn.utils import shuffle
newDf = shuffle(newDf)
#newDf.sample(10)
newDf.head()
newDf.shape
# Out:
# (17756, 3)

# %%
import torch
save_file = 'prepared_DPM_preprocessing.pkl'
newDf.to_pickle(save_file)
path_google_drive = F"/content/drive/My Drive/{save_file}" 
torch.save(save_file, path_google_drive)

# %%
from sklearn.model_selection import train_test_split

trainDF, testDF = train_test_split(newDf, test_size=0.2)

# %%
save_file = 'train_DPM_preprocessing.pkl'
trainDF.to_pickle(save_file)
path_google_drive = F"/content/drive/My Drive/{save_file}" 
torch.save(save_file, path_google_drive)

# %%
save_file = 'test_DPM_preprocessing.pkl'
testDF.to_pickle(save_file)
path_google_drive = F"/content/drive/My Drive/{save_file}" 
torch.save(save_file, path_google_drive)

# %%
trainDFRead = pd.read_pickle("train_DPM_preprocessing.pkl")
trainDFRead.head()
# Out:
#      par_id                                           sentence  label
# 5123   7846   throwing any i think we should save every pen...      1
# 6716   7440  the second kind of promise was emotional and e...      0
# 824     920  the first lady reassured the women that presid...      0
# 6041   6686  director of the rsu kenute hare cautioned that...      0
# 5962   6600  the concession was designation for retired and...      0

# %%
trainDFRead.shape
# Out:
# (14204, 3)

# %%
testDFRead = pd.read_pickle("test_DPM_preprocessing.pkl")
testDFRead.head()
# Out:
#      par_id                                           sentence  label
# 7827   5756   that some 280000 people are now homeless i ve...      1
# 4542   5008  the crowd that you d expect around the terraco...      0
# 7306   7553   obama sidestepped congress on november 20 201...      1
# 3460   9823   people who undergo the transgendered process ...      1
# 7201   7966  a restaurant that is famous for giving free me...      0

# %%
testDFRead.shape
# Out:
# (3552, 3)
