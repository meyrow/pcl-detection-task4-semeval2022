# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp gdrive/MyDrive/dontpatronizeme_pcl.tsv .
# !cp gdrive/MyDrive/dontpatronizeme_categories.tsv .
# !cp gdrive/MyDrive/train_semeval_parids-labels.csv .
# !cp gdrive/MyDrive/dev_semeval_parids-labels.csv .
# !cp gdrive/MyDrive/orig_DPM_prepare.py .

# %%
import random
import os
from urllib import request

# %%
from orig_DPM_prepare import DPM_Prepare
dpm = DPM_Prepare('.', 'dontpatronizeme_pcl.tsv')

# %%
dpm.load_task1()
dpm.train_task1_df.head()
# Out:
#   par_id      art_id  ... label orig_label
# 0      1  @@24942188  ...     0          0
# 1      2  @@21968160  ...     0          0
# 2      3  @@16584954  ...     0          0
# 3      4   @@7811231  ...     0          0
# 4      5   @@1494111  ...     0          0
#
# [5 rows x 7 columns]

# %%
dpm.load_task2()
dpm.train_task2_df.head()
# Out:
# Map of label to numerical label:
# {'Unbalanced_power_relations': 0, 'Shallow_solution': 1, 'Presupposition': 2, 'Authority_voice': 3, 'Metaphors': 4, 'Compassion': 5, 'The_poorer_the_merrier': 6}
#   par_id      art_id  ... country                  label
# 0   4046  @@14767805  ...      us  [1, 0, 0, 1, 0, 0, 0]
# 1   1279   @@7896098  ...      ng  [0, 1, 0, 0, 0, 0, 0]
# 2   8330  @@17252299  ...      ng  [0, 0, 1, 0, 0, 0, 0]
# 3   4063   @@3002894  ...      ie  [1, 0, 0, 1, 1, 1, 0]
# 4   4089  @@25597822  ...      pk  [1, 0, 0, 0, 0, 0, 0]
#
# [5 rows x 6 columns]

# %%
dpm.load_orig_positive()
dpm.orig_positive_df.head(20)
# Out:
#    par_id      art_id  ... label orig_label
# 0      33   @@8301323  ...     0          0
# 1      34  @@24150149  ...     0          0
# 2      42   @@4591694  ...     0          0
# 3      77  @@22454828  ...     0          0
# 4      83   @@4672144  ...     0          0
# 5     107  @@16900972  ...     0          0
# 6     118  @@24885862  ...     0          0
# 7     149   @@1387882  ...     0          0
# 8     151  @@19974860  ...     0          0
# 9     152  @@18323373  ...     0          0
# 10    154  @@20663936  ...     0          0
# 11    155   @@4755947  ...     0          0
# 12    157  @@21712008  ...     0          0
# 13    171  @@18450304  ...     0          0
# 14    179  @@15574765  ...     0          0
# 15    187  @@24814760  ...     0          0
# 16    195   @@4478900  ...     0          0
# 17    197   @@7384248  ...     0          0
# 18    206  @@25312066  ...     0          0
# 19    228   @@4268545  ...     0          0
#
# [20 rows x 7 columns]

# %%
df1 = dpm.orig_positive_df
df1 = df1.rename(columns={'text': 'sentence'})
df1 = df1.assign(label=1)
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))
df1 = df1.drop(['art_id', 'keyword', 'country', 'orig_label'], axis = 1)

# Display 10 random rows from the data.
df1.sample(10)
# Out:
# Number of training sentences: 993
#     par_id                                           sentence  label
# 379   3954  """ if a single human being is rendered homele...      1
# 880   9282  for many poor families , the college is a very...      1
# 410   4263  christmas and new year are upon us , and famil...      1
# 575   6052  2017 budget : more needs to be done for disabl...      1
# 733   7615  feel good food : delete to feed donates 11 mea...      1
# 341   3453  """ the offer to take 20,000 syrians is welcom...      1
# 624   6420  "homeless children are "" living like refugees...      1
# 603   6284  practical ways to open the doors wider for our...      1
# 658   6852  it was through that experience guest decided t...      1
# 373   3861  "in time , when the housing backlog for the lo...      1

# %%
dpm.orig_positive_df.shape
# Out:
# (993, 7)

# %%
dpm.load_all_negative()
dpm.all_negative_df.head()
# Out:
#   par_id      art_id  ... label orig_label
# 0      1  @@24942188  ...     0          0
# 1      2  @@21968160  ...     0          0
# 2      3  @@16584954  ...     0          0
# 3      4   @@7811231  ...     0          0
# 4      5   @@1494111  ...     0          0
#
# [5 rows x 7 columns]

# %%
dpm.all_negative_df.shape
# Out:
# (9476, 7)

# %%
df2 = dpm.all_negative_df
df2 = df2.rename(columns={'text': 'sentence'})
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))
df2 = df2.drop(['art_id', 'keyword', 'country', 'orig_label'], axis = 1)

# Display 10 random rows from the data.
df2.sample(10)
# Out:
# Number of training sentences: 993
#      par_id                                           sentence  label
# 7592   8398  who has been responsible for the big advances ...      0
# 5322   5876  """ we 're starting to see u.s. production lev...      0
# 212     234  thailand does not recognise the status of any ...      0
# 1693   1893  all systems go polio-stricken fernando santos ...      0
# 8646   9546  "soles4souls , the nashville-based charity tha...      0
# 8508   9396  mr ariel told ministry of housing staff and of...      0
# 4125   4564  throughout atki 's efforts to organize migrant...      0
# 5784   6408  can tourism provide solutions for the long ter...      0
# 7837   8662  thalassemia patients need regular blood transf...      0
# 6235   6896  the three were given first aid at m ? decins s...      0

# %% [markdown]
# words

# %%
df1["sentence"].str.extractall('(\w+)').count()[0]
# Out:
# 48025

# %%
df2["sentence"].str.extractall('(\w+)').count()[0]
# Out:
# 412143

# %%
df1["sentence"].str.split().str.len().sum()
# Out:
# 53245

# %%
df2["sentence"].str.split().str.len().sum()
# Out:
# 453690

# %%
df1["sentence"].str.split().str.len().mean()
# Out:
# 53.620342396777446

# %%
df2["sentence"].str.split().str.len().mean()
# Out:
# 47.87779653862389

# %%
df1["sentence"].str.split().str.len().std()
# Out:
# 32.7799953299914

# %%
df2["sentence"].str.split().str.len().std()
# Out:
# 28.624683498183135

# %% [markdown]
# characters

# %%
df1["sentence"].str.len().sum()
# Out:
# 286435

# %%
df2["sentence"].str.len().sum()
# Out:
# 2514890

# %%
df1["sentence"].str.len().mean()
# Out:
# 288.45417925478347

# %%
df2["sentence"].str.len().mean()
# Out:
# 265.39573659772054

# %%
df1["sentence"].str.len().std()
# Out:
# 175.52479538663545

# %%
df2["sentence"].str.len().std()
# Out:
# 158.36987599931314
