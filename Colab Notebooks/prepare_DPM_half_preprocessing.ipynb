# %% [markdown]
# ### Random over-sampling

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp gdrive/MyDrive/dontpatronizeme_pcl.tsv .
# !cp gdrive/MyDrive/dontpatronizeme_categories.tsv .
# !cp gdrive/MyDrive/train_semeval_parids-labels.csv .
# !cp gdrive/MyDrive/dev_semeval_parids-labels.csv .
# !cp gdrive/MyDrive/DPM_preprocessing_over_sampling.py .

# %%
import random
import string
import os
from urllib import request

# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.2-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.2 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.2

# %%
from DPM_preprocessing_over_sampling import DPM_preprocessing
dpm = DPM_preprocessing('.', 'dontpatronizeme_pcl.tsv')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
dpm.load_task1()
dpm.train_task1_df.head()
# Out:
#   par_id      art_id  ... label orig_label
# 0      1  @@24942188  ...     0          0
# 1      2  @@21968160  ...     0          0
# 2      3  @@16584954  ...     0          0
# 3      4   @@7811231  ...     0          0
# 4      5   @@1494111  ...     0          0
#
# [5 rows x 7 columns]

# %%
dpm.train_task1_df.shape
# Out:
# (10469, 7)

# %%
dpm.load_task2()
dpm.train_task2_df.head()
# Out:
# Map of label to numerical label:
# {'Unbalanced_power_relations': 0, 'Shallow_solution': 1, 'Presupposition': 2, 'Authority_voice': 3, 'Metaphors': 4, 'Compassion': 5, 'The_poorer_the_merrier': 6}
#   par_id      art_id  ... country                  label
# 0   4046  @@14767805  ...      us  [1, 0, 0, 1, 0, 0, 0]
# 1   1279   @@7896098  ...      ng  [0, 1, 0, 0, 0, 0, 0]
# 2   8330  @@17252299  ...      ng  [0, 0, 1, 0, 0, 0, 0]
# 3   4063   @@3002894  ...      ie  [1, 0, 0, 1, 1, 1, 0]
# 4   4089  @@25597822  ...      pk  [1, 0, 0, 0, 0, 0, 0]
#
# [5 rows x 6 columns]

# %%
dpm.train_task2_df.shape
# Out:
# (993, 6)

# %% [markdown]
# invoke preprocessing when load_all_positive

# %%
dpm.load_all_positive()
dpm.all_positive_df.head(20)
# Out:
#    par_id  ...                                          text_span
# 0    4046  ...                 put their situation in perspective
# 1    4046  ...                  help them communicate with others
# 2    4046  ...                          who could provide support
# 3    4046  ...  plan for their needs and the needs of their child
# 4    4046  ...                 we also know that they can benefit
# 5    4046  ...  someone knowledgeable about resources they can...
# 6    1279  ...  washed and kissed the feet of muslim , orthodo...
# 7    8330  ...  many refugees do n't want to be resettled anyw...
# 8    4063  ...              desperately in need of a helping hand
# 9    4063  ...                                     a helping hand
# 10   4063  ...  a helping hand to enable them to re-build thei...
# 11   4063  ...      enable them to re-build their shattered lives
# 12   4063  ...                     re-build their shattered lives
# 13   4063  ...  desperately in need of a helping hand to enabl...
# 14   4089  ...  one can see a high rise and a flyover while un...
# 15   4089  ...  as you can see , my constituency is not confin...
# 16    432  ...               their catastrophic living conditions
# 17    432  ...                              the desperate attempt
# 18   4177  ...                          give hope to the hopeless
# 19   4177  ...                          give hope to the hopeless
#
# [20 rows x 7 columns]

# %%
dpm.all_positive_df.shape
# Out:
# (2760, 7)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = dpm.all_positive_df
df1 = df1.rename(columns={'text': 'sentence'})
df1 = df1.assign(label=1)
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))
df1 = df1.drop(['art_id', 'keyword', 'country', 'text_span'], axis = 1)

# Display 10 random rows from the data.
df1.sample(10)
# Out:
# Number of training sentences: 2,760
#      par_id                                           sentence  label
# 2141   3355   every time you contribute to this christmas k...      1
# 1700   2655   children with specialised nutritional support...      1
# 1090    567   10 at a curtain call of a performance in lond...      1
# 1659   9647   to endure darker days in the future with thos...      1
# 2117    846   reveals that coach s corner host ron maclean ...      1
# 2242    966   group became so highly concerned with a homel...      1
# 75     9587   slavery which in itself was an act of extreme...      1
# 205   10007   thousands of africans risking death in the se...      1
# 2351   5746   called on the general public to volunteer to ...      1
# 1837   2800   the root of this issue there is a fundamental...      1

# %%
dpm.all_positive_df.shape
# Out:
# (2760, 7)

# %%
dpm.load_all_negative()
dpm.all_negative_df.head()
# Out:
#   par_id      art_id  ... label orig_label
# 0      1  @@24942188  ...     0          0
# 1      2  @@21968160  ...     0          0
# 2      3  @@16584954  ...     0          0
# 3      4   @@7811231  ...     0          0
# 4      5   @@1494111  ...     0          0
#
# [5 rows x 7 columns]

# %%
dpm.all_negative_df.shape
# Out:
# (9476, 7)

# %%
df2 = dpm.all_negative_df
df2 = df2.rename(columns={'text': 'sentence'})
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))
df2 = df2.drop(['art_id', 'keyword', 'country', 'orig_label'], axis = 1)

# Display 10 random rows from the data.
df2.sample(10)
# Out:
# Number of training sentences: 2,760
#      par_id                                           sentence  label
# 882     987  ms lim s claims come as a highly critical parl...      0
# 220     243  the prime minister bill english has come out i...      0
# 7639   8448  loach remains just as passionate about social ...      0
# 3100   3442  southeast louisiana bucked national trends and...      0
# 6592   7299  my dear when she said the bleaching part i jus...      0
# 7426   8212  according to the nsn president prof ngozi nnam...      0
# 9442  10431  wuerzburg germany the islamic state group on t...      0
# 1429   1608  serkan yagmur owner of west ridge hots 584 wes...      0
# 2670   2972  the syrian army was ordered to shoot down demo...      0
# 4258   4707  ed ligocki executive director of timmins homel...      0

# %%
import pandas as pd
frames = [df1, df2]
newDf = pd.concat(frames)

from sklearn.utils import shuffle
newDf = shuffle(newDf)
#newDf.sample(10)
newDf.head()
newDf.shape
# Out:
# (12236, 3)

# %%
newDf.sample(10)
# Out:
#      par_id                                           sentence  label
# 226     250  bank of america s biggest competitors do nt ha...      0
# 3857   4269  a third one would be to reform the hukou syste...      0
# 2270   2879   are not a country when you comfortably watch ...      1
# 2495   2520   france french baker michel flamant who owes h...      1
# 2877   3196  while warriors spectators are expected to be v...      0
# 305    9982   at this year s om die dam deputy minister man...      1
# 1238   6347   was gathered that most of them are dying of m...      1
# 855     957  since recently my feelings of hopelessness hav...      0
# 2157  10391   men were rounded up into second world warlike...      1
# 8653   9553   the women members of lower house national ass...      0

# %%
import torch
save_file = 'prepared_DPM_half_preprocessing4.pkl'
newDf.to_pickle(save_file)
path_google_drive = F"/content/drive/My Drive/{save_file}" 
torch.save(save_file, path_google_drive)

# %%
from sklearn.model_selection import train_test_split

trainDF, testDF = train_test_split(newDf, test_size=0.2)

# %%
save_file = 'train_DPM_half_preprocessing4.pkl'
trainDF.to_pickle(save_file)
path_google_drive = F"/content/drive/My Drive/{save_file}" 
torch.save(save_file, path_google_drive)

# %%
save_file = 'test_DPM_half_preprocessing4.pkl'
testDF.to_pickle(save_file)
path_google_drive = F"/content/drive/My Drive/{save_file}" 
torch.save(save_file, path_google_drive)

# %%
#trainDFRead = pd.read_pickle("train_DPM_half_preprocessing.pkl")
#trainDFRead.head()

# %%
#trainDFRead.shape

# %%
#testDFRead = pd.read_pickle("test_DPM_half_preprocessing.pkl")
#testDFRead.head()

# %%
#testDFRead.shape
