# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp gdrive/MyDrive/dontpatronizeme_pcl.tsv .
# !cp gdrive/MyDrive/dontpatronizeme_categories.tsv .
# !cp gdrive/MyDrive/train_semeval_parids-labels.csv .
# !cp gdrive/MyDrive/dev_semeval_parids-labels.csv .
# !cp gdrive/MyDrive/DPM_preprocessing2.py .

# %%
import random
import string
import os
from urllib import request

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (1.3.2)

# %%
from DPM_preprocessing2 import DPM_preprocessing
dpm = DPM_preprocessing('.', 'dontpatronizeme_pcl.tsv')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
dpm.load_task1()
dpm.train_task1_df.head()
# Out:
#   par_id      art_id  ... label orig_label
# 0      1  @@24942188  ...     0          0
# 1      2  @@21968160  ...     0          0
# 2      3  @@16584954  ...     0          0
# 3      4   @@7811231  ...     0          0
# 4      5   @@1494111  ...     0          0
#
# [5 rows x 7 columns]

# %%
dpm.train_task1_df.shape
# Out:
# (10469, 7)

# %%
dpm.load_task2()
dpm.train_task2_df.head()
# Out:
# Map of label to numerical label:
# {'Unbalanced_power_relations': 0, 'Shallow_solution': 1, 'Presupposition': 2, 'Authority_voice': 3, 'Metaphors': 4, 'Compassion': 5, 'The_poorer_the_merrier': 6}
#   par_id      art_id  ... country                  label
# 0   4046  @@14767805  ...      us  [1, 0, 0, 1, 0, 0, 0]
# 1   1279   @@7896098  ...      ng  [0, 1, 0, 0, 0, 0, 0]
# 2   8330  @@17252299  ...      ng  [0, 0, 1, 0, 0, 0, 0]
# 3   4063   @@3002894  ...      ie  [1, 0, 0, 1, 1, 1, 0]
# 4   4089  @@25597822  ...      pk  [1, 0, 0, 0, 0, 0, 0]
#
# [5 rows x 6 columns]

# %%
dpm.train_task2_df.shape
# Out:
# (993, 6)

# %% [markdown]
# invoke preprocessing when load_all_positive

# %%
dpm.load_all_positive()
dpm.all_positive_df.head(20)
# Out:
#    par_id  ...                                          text_span
# 0    4046  ...                 put their situation in perspective
# 1    4046  ...                  help them communicate with others
# 2    4046  ...                          who could provide support
# 3    4046  ...  plan for their needs and the needs of their child
# 4    4046  ...                 we also know that they can benefit
# 5    4046  ...  someone knowledgeable about resources they can...
# 6    1279  ...  washed and kissed the feet of muslim , orthodo...
# 7    8330  ...  many refugees do n't want to be resettled anyw...
# 8    4063  ...              desperately in need of a helping hand
# 9    4063  ...                                     a helping hand
# 10   4063  ...  a helping hand to enable them to re-build thei...
# 11   4063  ...      enable them to re-build their shattered lives
# 12   4063  ...                     re-build their shattered lives
# 13   4063  ...  desperately in need of a helping hand to enabl...
# 14   4089  ...  one can see a high rise and a flyover while un...
# 15   4089  ...  as you can see , my constituency is not confin...
# 16    432  ...               their catastrophic living conditions
# 17    432  ...                              the desperate attempt
# 18   4177  ...                          give hope to the hopeless
# 19   4177  ...                          give hope to the hopeless
#
# [20 rows x 7 columns]

# %%
dpm.all_positive_df.shape
# Out:
# (2760, 7)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = dpm.all_positive_df
df1 = df1.rename(columns={'text': 'sentence'})
df1 = df1.assign(label=1)
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))
df1 = df1.drop(['art_id', 'keyword', 'country', 'text_span'], axis = 1)

# Display 10 random rows from the data.
df1.sample(10)
# Out:
# Number of training sentences: 2,760
#      par_id                                           sentence  label
# 1699   2655   progress from being irreversibly eroded more ...      1
# 1992   9458   noted that violence that can not be separated...      1
# 2213    353   future ban said we need to strengthen search ...      1
# 407    4684   them from male offenders addiction poverty un...      1
# 1639   1515   h rescuing the mentally ill h cumi provides h...      1
# 1359    763   to seek greener pastures in europe it is sad ...      1
# 1354    763   of the result now is the massive exodus of af...      1
# 2409   9037   said david miliband irc president and ceo she...      1
# 876    3120   immigrant to a developed country lives in two...      1
# 2680   7164   of internally displaced persons idps belongin...      1

# %%
dpm.all_positive_df.shape
# Out:
# (2760, 7)

# %%
dpm.load_all_negative()
dpm.all_negative_df.head()
# Out:
#   par_id      art_id  ... label orig_label
# 0      1  @@24942188  ...     0          0
# 1      2  @@21968160  ...     0          0
# 2      3  @@16584954  ...     0          0
# 3      4   @@7811231  ...     0          0
# 4      5   @@1494111  ...     0          0
#
# [5 rows x 7 columns]

# %%
dpm.all_negative_df.shape
# Out:
# (9476, 7)

# %%
df2 = dpm.all_negative_df
df2 = df2.rename(columns={'text': 'sentence'})
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))
df2 = df2.drop(['art_id', 'keyword', 'country', 'orig_label'], axis = 1)

# Display 10 random rows from the data.
df2.sample(10)
# Out:
# Number of training sentences: 2,760
#      par_id                                           sentence  label
# 3417   3788  federal appeal on refugee healthcare cuts post...      0
# 960    1076   a brawl broke out in the southern part of the...      0
# 6036   6679  pie replaces the common law action whereby own...      0
# 6263   6927  the sri lankan government is keen on getting a...      0
# 6311   6983  minister of local government and community dev...      0
# 7960   8798  the naca report also observed that violence ag...      0
# 3077   3418  new york hollywood actress lindsay lohan recen...      0
# 6060   6710  he said i think we re going back to the days w...      0
# 3683   4077  the number of cholera infections in the port t...      0
# 7309   8083  other changes in bill c31 include reducing the...      0

# %%
import pandas as pd
frames = [df1, df2]
newDf = pd.concat(frames)

from sklearn.utils import shuffle
newDf = shuffle(newDf)
#newDf.sample(10)
newDf.head()
newDf.shape
# Out:
# (12236, 3)

# %%
import torch
save_file = 'imbalance_prepared_DPM_preprocessing.pkl'
newDf.to_pickle(save_file)
path_google_drive = F"/content/drive/My Drive/{save_file}" 
torch.save(save_file, path_google_drive)

# %%
from sklearn.model_selection import train_test_split

trainDF, testDF = train_test_split(newDf, test_size=0.2)

# %%
save_file = 'imbalance_train_DPM_preprocessing.pkl'
trainDF.to_pickle(save_file)

# %%
save_file = 'imbalance_test_DPM_preprocessing.pkl'
testDF.to_pickle(save_file)

# %%
trainDFRead = pd.read_pickle("imbalance_train_DPM_preprocessing.pkl")
trainDFRead.head()
# Out:
#      par_id                                           sentence  label
# 99      105  satisfaction lies in permitting others to live...      0
# 7866   8693  terminal remission which means no seizures for...      0
# 5321   5875  the collapse of oil prices has had a far more ...      0
# 813    9488   foundation became an oasis for grant s pen re...      1
# 4756   5247  assure action against illegal immigrants amp e...      0

# %%
trainDFRead.shape
# Out:
# (9788, 3)

# %%
testDFRead = pd.read_pickle("imbalance_test_DPM_preprocessing.pkl")
testDFRead.head()
# Out:
#      par_id                                           sentence  label
# 4537   5003  that young men in this city are hopelessly bro...      0
# 408    4684   unemployment physical and mental illness phys...      1
# 3838   4248  this is a day that should not a be day of desp...      0
# 6522   7221  officials have said that those rohingya now in...      0
# 467    6260   has managed to accept immigrants yet it keeps...      1

# %%
testDFRead.shape
# Out:
# (2448, 3)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/*.pkl -r gdrive/MyDrive/Imbalance_prepare/

# %%
newDf.shape
# Out:
# (12236, 3)
