# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp gdrive/MyDrive/preparedDataSet3.pkl .
pip install nltk

# %%
import pandas as pd  
dataSetLowerCase = pd.read_pickle(r'preparedDataSet3.pkl')
# Out:
#      par_id                                           sentence  label
# 8738   9649  "an analysis of requests by federal officials ...      0
# 1184   6715  so assured government assistance in future for...      1
# 2572   3489  mr vigbedor urged the traditional leaders to b...      1
# 1103   1237  "mai chen , founder of myadvice.legal , said "...      0
# 5173   5708  the study showed that as many as 80 percent of...      0

# %%
column_B = dataSetLowerCase.iloc[:, 1]
column_B
# Out:
# 8738    "an analysis of requests by federal officials ...
# 1184    so assured government assistance in future for...
# 2572    mr vigbedor urged the traditional leaders to b...
# 1103    "mai chen , founder of myadvice.legal , said "...
# 5173    the study showed that as many as 80 percent of...
#                               ...
# 3246    in partnership with association of persons wit...
# 1504    meanwhile , amnesty international had requeste...
# 8554    but he said the findings should not be taken a...
# 9461         it is more like a town than a refugee camp .
# 371      space of a week , four beautiful young women ...
# Name: sentence, Length: 12236, dtype: object

# %%
tokenizer = nltk.RegexpTokenizer(r"\w+")
new_words = tokenizer.tokenize(sentence)
