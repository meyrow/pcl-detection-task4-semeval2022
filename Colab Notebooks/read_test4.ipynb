# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp gdrive/MyDrive/task4_test.tsv .

# %%
# !cp gdrive/MyDrive/DPM_preprocessing_test.py .

# %%
import random
import string
import os
from urllib import request

# %%
# !pip install unidecode
# Out:
# ...
#      |████████████████████████████████| 235 kB 14.3 MB/s
# ...

# %%
from DPM_preprocessing_test import DPM_preprocessing
dpm = DPM_preprocessing('.', 'task4_test.tsv')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
dpm.load_task1()
dpm.train_task1_df.head()
# Out:
#   par_id                                               text
# 0    t_0  in the meantime , conservatives are working to...
# 1    t_1  in most poor households with no education chil...
# 2    t_2  the real question is not whether immigration i...
# 3    t_3  in total , the country 's immigrant population...
# 4    t_4  members of the church , which is part of ken c...

# %%
dpm.load_all_test()
dpm.all_test_df.head()
# Out:
#   par_id                                               text
# 0    t_0  in the meantime conservatives are working to w...
# 1    t_1  in most poor households with no education chil...
# 2    t_2  the real question is not whether immigration i...
# 3    t_3  in total the country s immigrant population ha...
# 4    t_4  members of the church which is part of ken cop...

# %%
dpm.all_test_df.shape
# Out:
# (3832, 2)

# %%
dpm.load_bert_test()
dpm.bert_test_df.head()
# Out:
#   par_id                                               text
# 0    t_0  in the meantime conservatives are working to w...
# 1    t_1  in most poor households with no education chil...
# 2    t_2  the real question is not whether immigration i...
# 3    t_3  in total the country s immigrant population ha...
# 4    t_4  members of the church which is part of ken cop...

# %%
dpm.bert_test_df.shape
# Out:
# (4075, 2)

# %%
mask = (dpm.bert_test_df['text'].str.len() > 500)
df = dpm.bert_test_df.loc[mask]
df.head()
# Out:
#     par_id                                               text
# 257  t_242  according to the statistics of bureau of manpo...
# 260  t_245  there are as many profiles of the potentially ...
# 279  t_264  the iom explained further that over the past t...
# 716  t_694   in bogot and in colombia a vast community jou...
# 908  t_877  they can afford to do their part to alleviate ...

# %%
df = dpm.bert_test_df[dpm.bert_test_df["par_id"].duplicated()]
df.head()
# Out:
#    par_id                                               text
# 12   t_12  f caring societies governments concerned would...
# 36   t_35  s in these positions are you still manifesting...
# 42   t_40  s from the island american diplomats including...
# 53   t_50   for syrian lives territorial integrity nation...
# 73   t_69  apartments divided into tiny living spaces ren...

# %%
mask = (dpm.bert_test_df['par_id'] == 't_69')
df = dpm.bert_test_df.loc[mask]
df.head()
# Out:
#    par_id                                               text
# 72   t_69  on tuesday december 2 beijingbased artists son...
# 73   t_69  apartments divided into tiny living spaces ren...

# %%
mask = (dpm.all_test_df['par_id'] == 't_69')
df = dpm.all_test_df.loc[mask]
df.head()
# Out:
#    par_id                                               text
# 68   t_69  on tuesday december 2 beijingbased artists son...

# %%
df_dupli = dpm.all_test_df[dpm.all_test_df["par_id"].duplicated()]
df_dupli.head()
# Out:
# Empty DataFrame
# Columns: [par_id, text]
# Index: []

# %%
df1 = dpm.all_test_df
df1 = df1.rename(columns={'text': 'sentence'})
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))

# Display 10 random rows from the data.
df1.sample(10)
# Out:
# Number of training sentences: 3,832
#       par_id                                           sentence
# 2003  t_2040   there are many more bigger branches still lea...
# 1258  t_1279            you or possibly me in need of vacation
# 3455  t_3515  to see how money influenced medication use res...
# 3413  t_3472  under the agreement filippo grandi the un comm...
# 109    t_111  complaints on operation to get rid of illegal ...
# 1594  t_1622  what this does show is that there is currently...
# 1267  t_1288  turkish coastguards drove their boat back on t...
# 747    t_760  he said when matters get bad in an economy peo...
# 3506  t_3566  it hinted at a lack of confidence and convicti...
# 3063  t_3120  he told the envoys that ghana would always pla...

# %%
df2 = dpm.bert_test_df
df2 = df2.rename(columns={'text': 'sentence'})
# Report the number of sentences.
print('Number of training sentences: {:,}\n'.format(df1.shape[0]))

# Display 10 random rows from the data.
df2.sample(10)
# Out:
# Number of training sentences: 3,832
#       par_id                                           sentence
# 1835  t_1769  a psychologist for the international rescue co...
# 207    t_196  turkey with 27 million registered syrian refug...
# 845    t_818  he went on the disabled list the next day and ...
# 2893  t_2777  labor disputes have become china s most preval...
# 1366  t_1315  reiterating his call for a reform of the dubli...
# 3722  t_3569  for a year he was homeless putting up with fri...
# 2079  t_2002  the serial criminal now serving a jail term of...
# 536    t_518  the ferocity of these arguments increase in di...
# 2298  t_2212  t takes a joan of arc and a steve jobs to go o...
# 2551  t_2453  while it was not donald trump s capture of the...

# %%
import numpy as np
measurer = np.vectorize(len)
res1 = measurer(df1.values.astype(str)).max(axis=0)
res1
# Out:
# array([   6, 2080])

# %%
df1["sentence"].str.len().max()
# Out:
# 2080

# %%
import numpy as np
measurer = np.vectorize(len)
res2 = measurer(df2.values.astype(str)).max(axis=0)
res2
# Out:
# array([  6, 511])

# %%
save_file = 'allTest.pkl'
df1.to_pickle(save_file)

# %%
save_file = 'bertTest.pkl'
df2.to_pickle(save_file)

# %%
# !cp /content/allTest.pkl -r gdrive/MyDrive/classicmodels/

# %%
# !cp /content/bertTest.pkl -r gdrive/MyDrive/bertModel/
